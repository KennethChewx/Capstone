# %%
import os
import cv2
import keras
import math
import random
import pathlib
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras import backend as K
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.preprocessing import image
from keras.engine import Layer
from keras.applications.inception_resnet_v2 import preprocess_input
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose, Input, Reshape, merge, concatenate, Activation, Dense, Dropout, Flatten, LeakyReLU
from keras.layers.normalization import BatchNormalization
from keras.callbacks import TensorBoard 
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential, Model
from keras.layers.core import RepeatVector
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, gray2rgb
from skimage.transform import resize
from skimage.io import imsave
from skimage import exposure

# %%
# Memory error, so to feed model in batches
batch_size = 10
train_dir = '../few_images/Gray'
validation = '../few_images/validation'

# %%
#custom image augmentation function
def custom_preprocessing(image):
    state = random.randint(0,2)
    if state == 0:
        processed_img = exposure.equalize_adapthist((image*1.0/255), clip_limit=0.02)
    elif state == 1:
        processed_img = exposure.equalize_hist(image)
    elif state == 2:
        p2, p98 = np.percentile(image, (2,98))
        processed_img = exposure.rescale_intensity(image)
    return processed_img

image_gen = ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip=True,
        preprocessing_function=custom_preprocessing)

# %%
# LAB range L (0,100); ab (-128,127)
# function to split training set X train, y train and produce augmented images       
def image_a_b_gen(batch_size):
    for i in image_gen.flow_from_directory(train_dir, batch_size=batch_size, class_mode=None, shuffle=False):
        lab_batch = (rgb2lab(i))
        X_train = lab_batch[:,:,:,0]
        X_train = X_train.reshape(X_train.shape+(1,))
        y_train = lab_batch[:,:,:,1:]
        yield ([X_train, y_train])

# %%
gray_batch.shape
# Out:
# (10, 256, 256)

# %%
for i in image_gen.flow_from_directory(validation, batch_size=batch_size, class_mode=None, shuffle=False):
    lab_batch = rgb2lab(i)
    gray_batch = gray2rgb(rgb2gray(i))
    lab_gray_batch = rgb2lab(gray_batch)
    X_train = gray_batch.reshape(gray_batch.shape+(1,))
    y_train = lab_batch[:,:,:,1:]
    break
# Out:
# Found 200 images belonging to 1 classes.

# %%
lab_scaled = (lab_batch + [0, 128, 128]) / [100, 255, 255]

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(25, 25),
                         sharex=True, sharey=True)
ax = axes.ravel()
ax[0].imshow(i[7])
ax[1].imshow(lab_batch[7])
ax[2].imshow(lab_batch[7][:,:,0])
ax[3].imshow(gray_batch[7])
ax[4].imshow(lab_scaled[7][:,:,:])
# Out:
# W0630 13:11:11.126475  8800 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
lab_scaled = (lab_batch + [0, 128, 128]) / [100, 255, 255]

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(25, 25),
                         sharex=True, sharey=True)
ax = axes.ravel()
ax[0].imshow(lab_batch[3])
ax[1].imshow(i[3])
ax[2].imshow(lab_batch[3][:,:,0])
ax[3].imshow(lab2rgb(lab_batch[3]))
ax[4].imshow(lab_scaled[3][:,:,:])
# Out:
# W0630 12:44:23.147730  8800 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Grayscale L + colored AB
cur = np.zeros((256, 256, 3))
cur[:,:,0] = lab_test[i][:,:,0]*100
cur[:,:,1:] = output[i]*100

# %%
class DSSIMObjective:
    def __init__(self, k1=0.01, k2=0.03, max_value=1.0):
        self.__name__ = 'DSSIMObjective'
        self.k1 = k1
        self.k2 = k2
        self.max_value = max_value
        self.backend = K.backend()

    def __int_shape(self, x):
        return K.int_shape(x) if self.backend == 'tensorflow' else K.shape(x)

    def __call__(self, y_true, y_pred):
        ch = K.shape(y_pred)[-1]

        def _fspecial_gauss(size, sigma):
            #Function to mimic the 'fspecial' gaussian MATLAB function.
            coords = np.arange(0, size, dtype=K.floatx())
            coords -= (size - 1 ) / 2.0
            g = coords**2
            g *= ( -0.5 / (sigma**2) )
            g = np.reshape (g, (1,-1)) + np.reshape(g, (-1,1) )
            g = K.constant ( np.reshape (g, (1,-1)) )
            g = K.softmax(g)
            g = K.reshape (g, (size, size, 1, 1)) 
            g = K.tile (g, (1,1,ch,1))
            return g
                  
        kernel = _fspecial_gauss(11,1.5)

        def reducer(x):
            return K.depthwise_conv2d(x, kernel, strides=(1, 1), padding='valid')

        c1 = (self.k1 * self.max_value) ** 2
        c2 = (self.k2 * self.max_value) ** 2
        
        mean0 = reducer(y_true)
        mean1 = reducer(y_pred)
        num0 = mean0 * mean1 * 2.0
        den0 = K.square(mean0) + K.square(mean1)
        luminance = (num0 + c1) / (den0 + c1)
        
        num1 = reducer(y_true * y_pred) * 2.0
        den1 = reducer(K.square(y_true) + K.square(y_pred))
        c2 *= 1.0 #compensation factor
        cs = (num1 - num0 + c2) / (den1 - den0 + c2)

        ssim_val = K.mean(luminance * cs, axis=(-3, -2) )
        return K.mean( (1.0 - ssim_val ) / 2.0 )

# %%
ssim_loss = DSSIMObjective()

# %%
model = Sequential()

#Downsampling batch
model.add(InputLayer(input_shape=(256, 256, 1)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))                     
model.add(BatchNormalization())                                               #(bs,256, 256,64)
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', strides=2))            
model.add(BatchNormalization())                                               #(bs,128,128,64)
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))                     
model.add(BatchNormalization())                                               #(bs,128,128,128)
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', strides=2))          
model.add(BatchNormalization())                                               #(bs,64,64,128)
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))                     
model.add(BatchNormalization())                                               #(bs,64,64,256)
model.add(Conv2D(256, (3, 3), activation='relu', padding='same', strides=2))            
model.add(BatchNormalization())                                               #(bs,32,32,256)
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))                     
model.add(BatchNormalization())                                               #(bs,32,32,512)

#Upsampling batch
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))        
model.add(BatchNormalization())
model.add(Dropout(0.5))                                                       #(bs,32,32,512)
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))     
model.add(BatchNormalization())
model.add(Dropout(0.5))                                                       #(bs,32,32,256)
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))        
model.add(BatchNormalization())
model.add(Dropout(0.5))                                                       #(bs,32,32,128)
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))        
model.add(BatchNormalization()) 
model.add(UpSampling2D((2, 2)))                                               #(bs,64,64,64)
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))        
model.add(BatchNormalization())
model.add(UpSampling2D((2, 2)))                                               #(bs,128,128,32)
model.add(Conv2D(2, (3, 3), activation='tanh', padding='same'))         
model.add(UpSampling2D((2, 2)))                                               #(bs,256,256,2)

# Finish model
model.compile(optimizer='adam', loss=ssim_loss ,metrics=['mse','mean_absolute_error'])

# %%
# Train model
model.fit_generator(image_a_b_gen(batch_size), steps_per_epoch=2, epochs=100)
# Out:
# Epoch 1/100
# Found 100 images belonging to 2 classes.
# 2/2 [==============================] - 145s 72s/step - loss: 0.4992 - mean_squared_error: 0.5116 - DSSIMObjective: 0.4992 - mean_absolute_error: 0.6377
# Epoch 2/100
# 2/2 [==============================] - 128s 64s/step - loss: 0.4931 - mean_squared_error: 0.6980 - DSSIMObjective: 0.4931 - mean_absolute_error: 0.7770
# Epoch 3/100
# 2/2 [==============================] - 129s 64s/step - loss: 0.4965 - mean_squared_error: 0.8696 - DSSIMObjective: 0.4965 - mean_absolute_error: 0.8979
# Epoch 4/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4911 - mean_squared_error: 0.8528 - DSSIMObjective: 0.4911 - mean_absolute_error: 0.8921
# Epoch 5/100
# 2/2 [==============================] - 129s 64s/step - loss: 0.4878 - mean_squared_error: 0.8995 - DSSIMObjective: 0.4878 - mean_absolute_error: 0.9263
# Epoch 6/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4892 - mean_squared_error: 0.9021 - DSSIMObjective: 0.4892 - mean_absolute_error: 0.9286
# Epoch 7/100
# 2/2 [==============================] - 125s 62s/step - loss: 0.4879 - mean_squared_error: 0.8942 - DSSIMObjective: 0.4879 - mean_absolute_error: 0.9248
# Epoch 8/100
# 2/2 [==============================] - 123s 62s/step - loss: 0.4884 - mean_squared_error: 0.8805 - DSSIMObjective: 0.4884 - mean_absolute_error: 0.9130
# Epoch 9/100
# 2/2 [==============================] - 127s 64s/step - loss: 0.4867 - mean_squared_error: 0.8734 - DSSIMObjective: 0.4867 - mean_absolute_error: 0.9112
# Epoch 10/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4880 - mean_squared_error: 0.8905 - DSSIMObjective: 0.4880 - mean_absolute_error: 0.9218
# Epoch 11/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4833 - mean_squared_error: 0.8576 - DSSIMObjective: 0.4833 - mean_absolute_error: 0.9048
# Epoch 12/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4860 - mean_squared_error: 0.9058 - DSSIMObjective: 0.4860 - mean_absolute_error: 0.9316
# Epoch 13/100
# 2/2 [==============================] - 140s 70s/step - loss: 0.4842 - mean_squared_error: 0.8808 - DSSIMObjective: 0.4842 - mean_absolute_error: 0.9191
# Epoch 14/100
# 2/2 [==============================] - 142s 71s/step - loss: 0.4844 - mean_squared_error: 0.8425 - DSSIMObjective: 0.4844 - mean_absolute_error: 0.8957
# Epoch 15/100
# 2/2 [==============================] - 140s 70s/step - loss: 0.4845 - mean_squared_error: 0.8784 - DSSIMObjective: 0.4845 - mean_absolute_error: 0.9149
# Epoch 16/100
# 2/2 [==============================] - 137s 69s/step - loss: 0.4862 - mean_squared_error: 0.9086 - DSSIMObjective: 0.4862 - mean_absolute_error: 0.9354
# Epoch 17/100
# 2/2 [==============================] - 138s 69s/step - loss: 0.4847 - mean_squared_error: 0.8669 - DSSIMObjective: 0.4847 - mean_absolute_error: 0.9131
# Epoch 18/100
# 2/2 [==============================] - 132s 66s/step - loss: 0.4844 - mean_squared_error: 0.8687 - DSSIMObjective: 0.4844 - mean_absolute_error: 0.9119
# Epoch 19/100
# 2/2 [==============================] - 131s 65s/step - loss: 0.4845 - mean_squared_error: 0.8258 - DSSIMObjective: 0.4845 - mean_absolute_error: 0.8862
# Epoch 20/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4860 - mean_squared_error: 0.8194 - DSSIMObjective: 0.4860 - mean_absolute_error: 0.8805
# Epoch 21/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4856 - mean_squared_error: 0.8216 - DSSIMObjective: 0.4856 - mean_absolute_error: 0.8839
# Epoch 22/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4856 - mean_squared_error: 0.8025 - DSSIMObjective: 0.4856 - mean_absolute_error: 0.8683
# Epoch 23/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4851 - mean_squared_error: 0.7431 - DSSIMObjective: 0.4851 - mean_absolute_error: 0.8296
# Epoch 24/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4838 - mean_squared_error: 0.7878 - DSSIMObjective: 0.4838 - mean_absolute_error: 0.8542
# Epoch 25/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4824 - mean_squared_error: 0.7874 - DSSIMObjective: 0.4824 - mean_absolute_error: 0.8600
# Epoch 26/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4820 - mean_squared_error: 0.6750 - DSSIMObjective: 0.4820 - mean_absolute_error: 0.7769
# Epoch 27/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4835 - mean_squared_error: 0.7858 - DSSIMObjective: 0.4835 - mean_absolute_error: 0.8631
# Epoch 28/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4838 - mean_squared_error: 0.6330 - DSSIMObjective: 0.4838 - mean_absolute_error: 0.7543
# Epoch 29/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4801 - mean_squared_error: 0.6574 - DSSIMObjective: 0.4801 - mean_absolute_error: 0.7677
# Epoch 30/100
# 2/2 [==============================] - 125s 62s/step - loss: 0.4809 - mean_squared_error: 0.4059 - DSSIMObjective: 0.4809 - mean_absolute_error: 0.5464
# Epoch 31/100
# 2/2 [==============================] - 132s 66s/step - loss: 0.4824 - mean_squared_error: 0.6820 - DSSIMObjective: 0.4824 - mean_absolute_error: 0.7923
# Epoch 32/100
# 2/2 [==============================] - 137s 68s/step - loss: 0.4860 - mean_squared_error: 0.6536 - DSSIMObjective: 0.4860 - mean_absolute_error: 0.7735
# Epoch 33/100
# 2/2 [==============================] - 136s 68s/step - loss: 0.4784 - mean_squared_error: 0.5273 - DSSIMObjective: 0.4784 - mean_absolute_error: 0.6821
# Epoch 34/100
# 2/2 [==============================] - 131s 66s/step - loss: 0.4799 - mean_squared_error: 0.4263 - DSSIMObjective: 0.4799 - mean_absolute_error: 0.5704
# Epoch 35/100
# 2/2 [==============================] - 131s 65s/step - loss: 0.4791 - mean_squared_error: 0.4179 - DSSIMObjective: 0.4791 - mean_absolute_error: 0.5818
# Epoch 36/100
# 2/2 [==============================] - 145s 73s/step - loss: 0.4744 - mean_squared_error: 0.3775 - DSSIMObjective: 0.4744 - mean_absolute_error: 0.5426
# Epoch 37/100
# 2/2 [==============================] - 138s 69s/step - loss: 0.4780 - mean_squared_error: 0.3545 - DSSIMObjective: 0.4780 - mean_absolute_error: 0.4998
# Epoch 38/100
# 2/2 [==============================] - 138s 69s/step - loss: 0.4781 - mean_squared_error: 0.3328 - DSSIMObjective: 0.4781 - mean_absolute_error: 0.4957
# Epoch 39/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4713 - mean_squared_error: 0.2376 - DSSIMObjective: 0.4713 - mean_absolute_error: 0.3756
# Epoch 40/100
# 2/2 [==============================] - 129s 64s/step - loss: 0.4880 - mean_squared_error: 0.2876 - DSSIMObjective: 0.4880 - mean_absolute_error: 0.4301
# Epoch 41/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4801 - mean_squared_error: 0.3212 - DSSIMObjective: 0.4801 - mean_absolute_error: 0.4868
# Epoch 42/100
# 2/2 [==============================] - 128s 64s/step - loss: 0.4771 - mean_squared_error: 0.2718 - DSSIMObjective: 0.4771 - mean_absolute_error: 0.4276
# Epoch 43/100
# 2/2 [==============================] - 129s 64s/step - loss: 0.4688 - mean_squared_error: 0.2551 - DSSIMObjective: 0.4688 - mean_absolute_error: 0.3965
# Epoch 44/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4780 - mean_squared_error: 0.2688 - DSSIMObjective: 0.4780 - mean_absolute_error: 0.4153
# Epoch 45/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4707 - mean_squared_error: 0.2486 - DSSIMObjective: 0.4707 - mean_absolute_error: 0.3991
# Epoch 46/100
# 2/2 [==============================] - 139s 69s/step - loss: 0.4816 - mean_squared_error: 0.1993 - DSSIMObjective: 0.4816 - mean_absolute_error: 0.3573
# Epoch 47/100
# 2/2 [==============================] - 133s 67s/step - loss: 0.4696 - mean_squared_error: 0.1566 - DSSIMObjective: 0.4696 - mean_absolute_error: 0.2963
# Epoch 48/100
# 2/2 [==============================] - 132s 66s/step - loss: 0.4750 - mean_squared_error: 0.1396 - DSSIMObjective: 0.4750 - mean_absolute_error: 0.2780
# Epoch 49/100
# 2/2 [==============================] - 134s 67s/step - loss: 0.4777 - mean_squared_error: 0.1330 - DSSIMObjective: 0.4777 - mean_absolute_error: 0.2705
# Epoch 50/100
# 2/2 [==============================] - 136s 68s/step - loss: 0.4745 - mean_squared_error: 0.1301 - DSSIMObjective: 0.4745 - mean_absolute_error: 0.2739
# Epoch 51/100
# 2/2 [==============================] - 131s 66s/step - loss: 0.4684 - mean_squared_error: 0.1321 - DSSIMObjective: 0.4684 - mean_absolute_error: 0.2638
# Epoch 52/100
# 2/2 [==============================] - 132s 66s/step - loss: 0.4660 - mean_squared_error: 0.1057 - DSSIMObjective: 0.4660 - mean_absolute_error: 0.2234
# Epoch 53/100
# 2/2 [==============================] - 138s 69s/step - loss: 0.4682 - mean_squared_error: 0.1898 - DSSIMObjective: 0.4682 - mean_absolute_error: 0.3669
# Epoch 54/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4582 - mean_squared_error: 0.1139 - DSSIMObjective: 0.4582 - mean_absolute_error: 0.2564
# Epoch 55/100
# 2/2 [==============================] - 132s 66s/step - loss: 0.4672 - mean_squared_error: 0.1281 - DSSIMObjective: 0.4672 - mean_absolute_error: 0.2549
# Epoch 56/100
# 2/2 [==============================] - 137s 68s/step - loss: 0.4652 - mean_squared_error: 0.1362 - DSSIMObjective: 0.4652 - mean_absolute_error: 0.2815
# Epoch 57/100
# 2/2 [==============================] - 136s 68s/step - loss: 0.4652 - mean_squared_error: 0.1108 - DSSIMObjective: 0.4652 - mean_absolute_error: 0.2467
# Epoch 58/100
# 2/2 [==============================] - 133s 66s/step - loss: 0.4596 - mean_squared_error: 0.1019 - DSSIMObjective: 0.4596 - mean_absolute_error: 0.2322
# Epoch 59/100
# 2/2 [==============================] - 136s 68s/step - loss: 0.4616 - mean_squared_error: 0.0971 - DSSIMObjective: 0.4616 - mean_absolute_error: 0.2203
# Epoch 60/100
# 2/2 [==============================] - 137s 69s/step - loss: 0.4649 - mean_squared_error: 0.1031 - DSSIMObjective: 0.4649 - mean_absolute_error: 0.2317
# Epoch 61/100
# 2/2 [==============================] - 139s 69s/step - loss: 0.4805 - mean_squared_error: 0.0846 - DSSIMObjective: 0.4805 - mean_absolute_error: 0.2051
# Epoch 62/100
# 2/2 [==============================] - 137s 68s/step - loss: 0.4663 - mean_squared_error: 0.1069 - DSSIMObjective: 0.4663 - mean_absolute_error: 0.2422
# Epoch 63/100
# 2/2 [==============================] - 150s 75s/step - loss: 0.4571 - mean_squared_error: 0.0957 - DSSIMObjective: 0.4571 - mean_absolute_error: 0.2261
# Epoch 64/100
# 2/2 [==============================] - 147s 73s/step - loss: 0.4671 - mean_squared_error: 0.1561 - DSSIMObjective: 0.4671 - mean_absolute_error: 0.3130
# Epoch 65/100
# 2/2 [==============================] - 139s 70s/step - loss: 0.4665 - mean_squared_error: 0.0978 - DSSIMObjective: 0.4665 - mean_absolute_error: 0.2193
# Epoch 66/100
# 2/2 [==============================] - 138s 69s/step - loss: 0.4626 - mean_squared_error: 0.0962 - DSSIMObjective: 0.4626 - mean_absolute_error: 0.2303
# Epoch 67/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4569 - mean_squared_error: 0.0855 - DSSIMObjective: 0.4569 - mean_absolute_error: 0.2099
# Epoch 68/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4608 - mean_squared_error: 0.0897 - DSSIMObjective: 0.4608 - mean_absolute_error: 0.2171
# Epoch 69/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4660 - mean_squared_error: 0.0651 - DSSIMObjective: 0.4660 - mean_absolute_error: 0.1816
# Epoch 70/100
# 2/2 [==============================] - 136s 68s/step - loss: 0.4700 - mean_squared_error: 0.0900 - DSSIMObjective: 0.4700 - mean_absolute_error: 0.2105
# Epoch 71/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4584 - mean_squared_error: 0.0860 - DSSIMObjective: 0.4584 - mean_absolute_error: 0.2051
# Epoch 72/100
# 2/2 [==============================] - 133s 66s/step - loss: 0.4629 - mean_squared_error: 0.1088 - DSSIMObjective: 0.4629 - mean_absolute_error: 0.2539
# Epoch 73/100
# 2/2 [==============================] - 134s 67s/step - loss: 0.4588 - mean_squared_error: 0.0808 - DSSIMObjective: 0.4588 - mean_absolute_error: 0.1989
# Epoch 74/100
# 2/2 [==============================] - 138s 69s/step - loss: 0.4585 - mean_squared_error: 0.0796 - DSSIMObjective: 0.4585 - mean_absolute_error: 0.1906
# Epoch 75/100
# 2/2 [==============================] - 137s 68s/step - loss: 0.4606 - mean_squared_error: 0.1132 - DSSIMObjective: 0.4606 - mean_absolute_error: 0.2590
# Epoch 76/100
# 2/2 [==============================] - 135s 67s/step - loss: 0.4562 - mean_squared_error: 0.0927 - DSSIMObjective: 0.4562 - mean_absolute_error: 0.2239
# Epoch 77/100
# 2/2 [==============================] - 142s 71s/step - loss: 0.4585 - mean_squared_error: 0.0668 - DSSIMObjective: 0.4585 - mean_absolute_error: 0.1794
# Epoch 78/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4603 - mean_squared_error: 0.0788 - DSSIMObjective: 0.4603 - mean_absolute_error: 0.2052
# Epoch 79/100
# 2/2 [==============================] - 136s 68s/step - loss: 0.4532 - mean_squared_error: 0.0694 - DSSIMObjective: 0.4532 - mean_absolute_error: 0.1840
# Epoch 80/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4644 - mean_squared_error: 0.0617 - DSSIMObjective: 0.4644 - mean_absolute_error: 0.1740
# Epoch 81/100
# 2/2 [==============================] - 129s 64s/step - loss: 0.4584 - mean_squared_error: 0.0683 - DSSIMObjective: 0.4584 - mean_absolute_error: 0.1874
# Epoch 82/100
# 2/2 [==============================] - 129s 64s/step - loss: 0.4552 - mean_squared_error: 0.0639 - DSSIMObjective: 0.4552 - mean_absolute_error: 0.1756
# Epoch 83/100
# 2/2 [==============================] - 151s 75s/step - loss: 0.4544 - mean_squared_error: 0.0626 - DSSIMObjective: 0.4544 - mean_absolute_error: 0.1737
# Epoch 84/100
# 2/2 [==============================] - 146s 73s/step - loss: 0.4616 - mean_squared_error: 0.0835 - DSSIMObjective: 0.4616 - mean_absolute_error: 0.2104
# Epoch 85/100
# 2/2 [==============================] - 127s 63s/step - loss: 0.4630 - mean_squared_error: 0.0583 - DSSIMObjective: 0.4630 - mean_absolute_error: 0.1679
# Epoch 86/100
# 2/2 [==============================] - 126s 63s/step - loss: 0.4516 - mean_squared_error: 0.0714 - DSSIMObjective: 0.4516 - mean_absolute_error: 0.1890
# Epoch 87/100
# 2/2 [==============================] - 128s 64s/step - loss: 0.4508 - mean_squared_error: 0.0540 - DSSIMObjective: 0.4508 - mean_absolute_error: 0.1600
# Epoch 88/100
# 2/2 [==============================] - 128s 64s/step - loss: 0.4580 - mean_squared_error: 0.0829 - DSSIMObjective: 0.4580 - mean_absolute_error: 0.2105
# Epoch 89/100
# 2/2 [==============================] - 128s 64s/step - loss: 0.4647 - mean_squared_error: 0.0982 - DSSIMObjective: 0.4647 - mean_absolute_error: 0.2446
# Epoch 90/100
# 2/2 [==============================] - 128s 64s/step - loss: 0.4584 - mean_squared_error: 0.0828 - DSSIMObjective: 0.4584 - mean_absolute_error: 0.2140
# Epoch 91/100
# 2/2 [==============================] - 125s 62s/step - loss: 0.4514 - mean_squared_error: 0.0670 - DSSIMObjective: 0.4514 - mean_absolute_error: 0.1836
# Epoch 92/100
# 2/2 [==============================] - 122s 61s/step - loss: 0.4641 - mean_squared_error: 0.0534 - DSSIMObjective: 0.4641 - mean_absolute_error: 0.1595
# Epoch 93/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4752 - mean_squared_error: 0.0870 - DSSIMObjective: 0.4752 - mean_absolute_error: 0.2105
# Epoch 94/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4622 - mean_squared_error: 0.0800 - DSSIMObjective: 0.4622 - mean_absolute_error: 0.2093
# Epoch 95/100
# 2/2 [==============================] - 124s 62s/step - loss: 0.4583 - mean_squared_error: 0.0617 - DSSIMObjective: 0.4583 - mean_absolute_error: 0.1766
# Epoch 96/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4543 - mean_squared_error: 0.0648 - DSSIMObjective: 0.4543 - mean_absolute_error: 0.1797
# Epoch 97/100
# 2/2 [==============================] - 129s 65s/step - loss: 0.4537 - mean_squared_error: 0.0579 - DSSIMObjective: 0.4537 - mean_absolute_error: 0.1637
# Epoch 98/100
# 2/2 [==============================] - 130s 65s/step - loss: 0.4680 - mean_squared_error: 0.0612 - DSSIMObjective: 0.4680 - mean_absolute_error: 0.1755
# Epoch 99/100
# 2/2 [==============================] - 133s 67s/step - loss: 0.4559 - mean_squared_error: 0.0616 - DSSIMObjective: 0.4559 - mean_absolute_error: 0.1770
# Epoch 100/100
# 2/2 [==============================] - 134s 67s/step - loss: 0.4568 - mean_squared_error: 0.0599 - DSSIMObjective: 0.4568 - mean_absolute_error: 0.1745

# %%
model.save('C:/Users/n3rDx/Desktop/Homework Upload/Capstone/5th_expt_lab_tanh_100_2categories.hdf5')

# %%
# Load black and white images
test = []
for filename in os.listdir('../few_images/Test'):
        test.append(img_to_array(load_img('C:/Users/n3rDx/Desktop/Homework Upload/Capstone/few_images/test/'+filename)))
lab_test = (rgb2lab(test)[:,:,:,0])*1.0/10000.0
lab_test = lab_test.reshape(lab_test.shape+(1,))

# %%
# Test model
output = model.predict(lab_test)

# %%
lab_test.max()
# Out:
# 0.9341571978788683

# %%
# Output colorizations
for i in range(len(output)):
    cur = np.zeros((256, 256, 3))
    cur[:,:,0] = lab_test[i][:,:,0]*100
    cur[:,:,1:] = output[i]*100
    #result = np.concatenate((lab_test[i], output[i]), axis=2)
    picture = lab2rgb(cur).astype('uint8')
    imsave("C:/Users/n3rDx/Desktop/Homework Upload/Capstone/results/"+str(i)+".jpg", picture)
# Out:
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 682 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2309 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 305 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 31 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 29 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 205 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 481 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 38 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 283 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 331 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 319 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 33 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 233 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 274 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 253 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 887 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 174 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 906 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1049 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1492 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 104 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 20 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1626 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 409 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 68 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 180 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 36 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 69 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 857 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 187 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 79 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 265 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1703 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2717 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2482 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 135 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 15 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 34 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 255 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 330 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 722 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 8 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 12 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 95 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 282 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 199 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 56 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 22 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 540 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 261 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 101 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 948 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 413 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 317 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 645 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 219 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 473 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)

# %%
# Out:
# 0.9979993

# %%
# summarize history for accuracy
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('model mean square error')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Structural Similarity Index')
plt.ylabel('SSIM')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
