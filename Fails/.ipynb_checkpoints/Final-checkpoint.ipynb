# %%
import os
import cv2
import keras
import math
import random
import pathlib
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras import backend as K
from keras.preprocessing import image
from keras.engine import Layer
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose, Input, Reshape, merge, concatenate, Activation, Dense, Dropout, Flatten, LeakyReLU
from keras.layers.normalization import BatchNormalization
from keras.callbacks import TensorBoard 
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential, Model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, gray2rgb
from skimage.transform import resize
from skimage.io import imsave
from skimage import exposure
# Out:
# Using TensorFlow backend.

# %%
# Memory error, so to feed model in batches
batch_size = 20
train_dir = '../Capstone/train/'

# %%
#custom image augmentation function
def custom_preprocessing(image):
    state = random.randint(0,1)
    if state == 0:
        processed_img = exposure.equalize_adapthist((image*1.0/255), clip_limit=0.02)
    elif state == 1:
        p2, p98 = np.percentile(image, (2,98))
        processed_img = exposure.rescale_intensity(image, in_range=(p2,p98))
    return processed_img

image_gen = ImageDataGenerator(
        shear_range=0.4,
        zoom_range=0.4,
        horizontal_flip=True,
        vertical_flip=True,
        preprocessing_function=custom_preprocessing)

# %%
# LAB range L (0,100); ab (-128,127)
# a is green - red ; b is blue -yellow
# function to split training set X train, y train and produce augmented images       
def image_a_b_gen(batch_size):
    for i in image_gen.flow_from_directory(train_dir, batch_size=batch_size, class_mode=None, shuffle=False):
        lab_batch = (rgb2lab(i))                         #images comes in as [0,1]   --> lab_batch = [0:100, -128:128, -128:128]
        #normalize the ab channels to 0-1
        lab_scaled = (lab_batch) / [100, 128, 128]       #lab_scaled is in [0:1,-1:1,-1:1]
        X_train = lab_scaled[:,:,:,0]
        X_train = X_train.reshape(X_train.shape+(1,))
        y_train = lab_scaled[:,:,:,1:]
        yield ([X_train, y_train])

# %%
for i in image_gen.flow_from_directory(train_dir, batch_size=batch_size, class_mode=None, shuffle=False):
    lab_batch = (rgb2lab(i))                         #images comes in as [0,1]   --> lab_batch = [0:100, -128:128, -128:128]
    #normalize the ab channels to 0-1
    lab_scaled = (lab_batch) / [100, 128, 128]       #lab_scaled is in [0:1,-1:1,-1:1]
    X_train = lab_scaled[:,:,:,0]
    X_train = X_train.reshape(X_train.shape+(1,))
    y_train = lab_scaled[:,:,:,1:]
    break
# Out:
# Found 2000 images belonging to 1 classes.

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(25, 25),
                         sharex=True, sharey=True)
ax = axes.ravel()
ax[0].imshow(i[2])
ax[1].imshow(lab_scaled[2])
ax[2].imshow(lab_batch[2])
ax[3].imshow(lab2rgb(lab_batch[2]))
# Out:
# W0702 18:16:02.920021  4452 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0702 18:16:02.924025  4452 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class DSSIMObjective:
    def __init__(self, k1=0.01, k2=0.03, max_value=1.0):
        self.__name__ = 'DSSIMObjective'
        self.k1 = k1
        self.k2 = k2
        self.max_value = max_value
        self.backend = K.backend()

    def __int_shape(self, x):
        return K.int_shape(x) if self.backend == 'tensorflow' else K.shape(x)

    def __call__(self, y_true, y_pred):
        ch = K.shape(y_pred)[-1]

        def _fspecial_gauss(size, sigma):
            #Function to mimic the 'fspecial' gaussian MATLAB function.
            coords = np.arange(0, size, dtype=K.floatx())
            coords -= (size - 1 ) / 2.0
            g = coords**2
            g *= ( -0.5 / (sigma**2) )
            g = np.reshape (g, (1,-1)) + np.reshape(g, (-1,1) )
            g = K.constant ( np.reshape (g, (1,-1)) )
            g = K.softmax(g)
            g = K.reshape (g, (size, size, 1, 1)) 
            g = K.tile (g, (1,1,ch,1))
            return g
                  
        kernel = _fspecial_gauss(11,1.5)

        def reducer(x):
            return K.depthwise_conv2d(x, kernel, strides=(1, 1), padding='valid')

        c1 = (self.k1 * self.max_value) ** 2
        c2 = (self.k2 * self.max_value) ** 2
        
        mean0 = reducer(y_true)
        mean1 = reducer(y_pred)
        num0 = mean0 * mean1 * 2.0
        den0 = K.square(mean0) + K.square(mean1)
        luminance = (num0 + c1) / (den0 + c1)
        
        num1 = reducer(y_true * y_pred) * 2.0
        den1 = reducer(K.square(y_true) + K.square(y_pred))
        c2 *= 1.0 #compensation factor
        cs = (num1 - num0 + c2) / (den1 - den0 + c2)

        ssim_val = K.mean(luminance * cs, axis=(-3, -2) )
        return K.mean( (1.0 - ssim_val ) / 2.0 )

# %%
ssim_loss = DSSIMObjective()

# %%
model = Sequential()

#Downsampling batch
model.add(InputLayer(input_shape=(256, 256, 1)))
model.add(Conv2D(64, (3, 3),activation='relu', padding='same'))                                               #(bs,256, 256,64)
model.add(Conv2D(64, (3, 3), activation='relu',padding='same', strides=2))                                    #(bs,128,128,64)
model.add(Conv2D(128, (3, 3), activation='relu',padding='same'))                                              #(bs,128,128,128)
model.add(Conv2D(128, (3, 3), activation='relu',padding='same', strides=2))                                   #(bs,64,64,128)
model.add(Conv2D(256, (3, 3), activation='relu',padding='same'))                                              #(bs,64,64,256)
model.add(Conv2D(256, (3, 3), activation='relu',padding='same', strides=2))                                   #(bs,32,32,256)
model.add(Conv2D(512, (3, 3), activation='relu',padding='same'))                                              #(bs,32,32,512)

#Upsampling batch
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))        
model.add(Dropout(0.5))                                                       #(bs,32,32,512)
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))     
model.add(Dropout(0.5))                                                       #(bs,32,32,256)
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))        
model.add(Dropout(0.5))                                                       #(bs,32,32,128)
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))        
model.add(UpSampling2D((2, 2)))                                               #(bs,64,64,64)
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))        
model.add(UpSampling2D((2, 2)))                                               #(bs,128,128,32)
model.add(Conv2D(2, (3, 3), activation='tanh', padding='same'))         
model.add(UpSampling2D((2, 2)))                                               #(bs,256,256,2)

# Finish model
model.compile(optimizer='adam', loss=ssim_loss ,metrics=['mse','mean_absolute_error'])

# %%
# Train model
model.fit_generator(image_a_b_gen(batch_size), steps_per_epoch=10, epochs=100)
# Out:
# Epoch 1/100
# Found 2000 images belonging to 1 classes.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\util\dtype.py:135: UserWarning: Possible precision loss when converting from float32 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\util\dtype.py:135: UserWarning: Possible precision loss when converting from float64 to float32
#   .format(dtypeobj_in, dtypeobj_out))
# 10/10 [==============================] - 123s 12s/step - loss: 0.3997 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0717
# Epoch 2/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.4031 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0756
# Epoch 3/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3862 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0692
# Epoch 4/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4020 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0728
# Epoch 5/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4073 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0807
# Epoch 6/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3935 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0686
# Epoch 7/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4066 - mean_squared_error: 0.0156 - mean_absolute_error: 0.0817
# Epoch 8/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.3974 - mean_squared_error: 0.0127 - mean_absolute_error: 0.0728
# Epoch 9/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4039 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0715
# Epoch 10/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.4106 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0805
# Epoch 11/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.3960 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0712
# Epoch 12/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4045 - mean_squared_error: 0.0139 - mean_absolute_error: 0.0769
# Epoch 13/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.3864 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0695
# Epoch 14/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4026 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0718
# Epoch 15/100
# 10/10 [==============================] - 125s 12s/step - loss: 0.4076 - mean_squared_error: 0.0151 - mean_absolute_error: 0.0804
# Epoch 16/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.3926 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0685
# Epoch 17/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.4060 - mean_squared_error: 0.0151 - mean_absolute_error: 0.0809
# Epoch 18/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.3968 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0721
# Epoch 19/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.4084 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0723
# Epoch 20/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.4103 - mean_squared_error: 0.0143 - mean_absolute_error: 0.0797
# Epoch 21/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.3930 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0688
# Epoch 22/100
# 10/10 [==============================] - 125s 12s/step - loss: 0.4007 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0764
# Epoch 23/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.3846 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0700
# Epoch 24/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.4021 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0723
# Epoch 25/100
# 10/10 [==============================] - 129s 13s/step - loss: 0.4089 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0804
# Epoch 26/100
# 10/10 [==============================] - 126s 13s/step - loss: 0.3918 - mean_squared_error: 0.0109 - mean_absolute_error: 0.0679
# Epoch 27/100
# 10/10 [==============================] - 127s 13s/step - loss: 0.4061 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0808
# Epoch 28/100
# 10/10 [==============================] - 130s 13s/step - loss: 0.3973 - mean_squared_error: 0.0128 - mean_absolute_error: 0.0731
# Epoch 29/100
# 10/10 [==============================] - 128s 13s/step - loss: 0.4055 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0721
# Epoch 30/100
# 10/10 [==============================] - 128s 13s/step - loss: 0.4088 - mean_squared_error: 0.0137 - mean_absolute_error: 0.0775
# Epoch 31/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.3944 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0695
# Epoch 32/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4010 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0752
# Epoch 33/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3884 - mean_squared_error: 0.0129 - mean_absolute_error: 0.0713
# Epoch 34/100
# 10/10 [==============================] - 125s 13s/step - loss: 0.4023 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0726
# Epoch 35/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4058 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0783
# Epoch 36/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3927 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0688
# Epoch 37/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4062 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0811
# Epoch 38/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.3984 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0722
# Epoch 39/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4058 - mean_squared_error: 0.0124 - mean_absolute_error: 0.0732
# Epoch 40/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4090 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0772
# Epoch 41/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3926 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0682
# Epoch 42/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4017 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0749
# Epoch 43/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3862 - mean_squared_error: 0.0124 - mean_absolute_error: 0.0698
# Epoch 44/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4020 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0707
# Epoch 45/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4081 - mean_squared_error: 0.0149 - mean_absolute_error: 0.0800
# Epoch 46/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3950 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0686
# Epoch 47/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4060 - mean_squared_error: 0.0151 - mean_absolute_error: 0.0810
# Epoch 48/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3974 - mean_squared_error: 0.0130 - mean_absolute_error: 0.0736
# Epoch 49/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4054 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0716
# Epoch 50/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4093 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0781
# Epoch 51/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3948 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0701
# Epoch 52/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4023 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0757
# Epoch 53/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3855 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0699
# Epoch 54/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.4027 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0731
# Epoch 55/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.4077 - mean_squared_error: 0.0146 - mean_absolute_error: 0.0793
# Epoch 56/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3940 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0703
# Epoch 57/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.4037 - mean_squared_error: 0.0149 - mean_absolute_error: 0.0800
# Epoch 58/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.3972 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0713
# Epoch 59/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4061 - mean_squared_error: 0.0124 - mean_absolute_error: 0.0731
# Epoch 60/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.4087 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0776
# Epoch 61/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.3930 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0687
# Epoch 62/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.4021 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0756
# Epoch 63/100
# 10/10 [==============================] - 122s 12s/step - loss: 0.3863 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0698
# Epoch 64/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.4021 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0711
# Epoch 65/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.4073 - mean_squared_error: 0.0151 - mean_absolute_error: 0.0806
# Epoch 66/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.3930 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0699
# Epoch 67/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.4057 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0818
# Epoch 68/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.3967 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0717
# Epoch 69/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.4076 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0725
# Epoch 70/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.4095 - mean_squared_error: 0.0137 - mean_absolute_error: 0.0783
# Epoch 71/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.3917 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0689
# Epoch 72/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4037 - mean_squared_error: 0.0137 - mean_absolute_error: 0.0764
# Epoch 73/100
# 10/10 [==============================] - 129s 13s/step - loss: 0.3858 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0693
# Epoch 74/100
# 10/10 [==============================] - 124s 12s/step - loss: 0.3984 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0688
# Epoch 75/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.4100 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0807
# Epoch 76/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.3935 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0688
# Epoch 77/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.4045 - mean_squared_error: 0.0147 - mean_absolute_error: 0.0795
# Epoch 78/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.4000 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0726
# Epoch 79/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.4066 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0729
# Epoch 80/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.4091 - mean_squared_error: 0.0139 - mean_absolute_error: 0.0790
# Epoch 81/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.3950 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0701
# Epoch 82/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.4009 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0751
# Epoch 83/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.3867 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0703
# Epoch 84/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.4014 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0715
# Epoch 85/100
# 10/10 [==============================] - 127s 13s/step - loss: 0.4077 - mean_squared_error: 0.0146 - mean_absolute_error: 0.0792
# Epoch 86/100
# 10/10 [==============================] - 125s 13s/step - loss: 0.3943 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0689
# Epoch 87/100
# 10/10 [==============================] - 125s 13s/step - loss: 0.4047 - mean_squared_error: 0.0143 - mean_absolute_error: 0.0789
# Epoch 88/100
# 10/10 [==============================] - 123s 12s/step - loss: 0.3943 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0719
# Epoch 89/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.4060 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0724
# Epoch 90/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.4093 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0779
# Epoch 91/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.3948 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0712
# Epoch 92/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.4020 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0744
# Epoch 93/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.3888 - mean_squared_error: 0.0128 - mean_absolute_error: 0.0711
# Epoch 94/100
# 10/10 [==============================] - 118s 12s/step - loss: 0.4018 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0721
# Epoch 95/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.4083 - mean_squared_error: 0.0146 - mean_absolute_error: 0.0797
# Epoch 96/100
# 10/10 [==============================] - 119s 12s/step - loss: 0.3907 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0670
# Epoch 97/100
# 10/10 [==============================] - 120s 12s/step - loss: 0.4047 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0806
# Epoch 98/100
# 10/10 [==============================] - 121s 12s/step - loss: 0.3985 - mean_squared_error: 0.0128 - mean_absolute_error: 0.0731
# Epoch 99/100
# 10/10 [==============================] - 118s 12s/step - loss: 0.4058 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0721
# Epoch 100/100
# 10/10 [==============================] - 118s 12s/step - loss: 0.4090 - mean_squared_error: 0.0138 - mean_absolute_error: 0.0785

# %%
model.save('C:/Users/n3rDx/Desktop/Homework Upload/Capstone/Final_adam_peopleonly_lab_relu_NORM_100epochs_noBN.hdf5')

# %%
# Load black and white images
test = []
for filename in os.listdir('../Capstone/test/test/'):
        test.append(img_to_array(load_img('C:/Users/n3rDx/Desktop/Homework Upload/Capstone/test/test/'+filename)))
test = np.array(test).astype('float')*1.0/255   #Original image must come in as (0,1)
lab_test = (rgb2lab(test)[:,:,:,0])/100       #output after rgb2lab should be ([0:1,-1:1, -1:1])
lab_test = lab_test.reshape(lab_test.shape+(1,))

# %%
# Test model
output = model.predict(lab_test)
output*= 128

# %%
# Output colorizations
for i in range(len(output)):
    cur = np.zeros((256, 256, 3))
    cur[:,:,0] = lab_test[i][:,:,0]
    cur[:,:,1:] = output[i]
    cur = (cur * [100, 128, 128])
    picture = lab2rgb(cur)
    picture *= 255
    imsave("C:/Users/n3rDx/Desktop/Homework Upload/Capstone/results/"+str(i)+".jpg", picture.astype('uint8'))
# Out:
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 45042 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5565 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 27116 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 14 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2043 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5753 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13421 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13512 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 40567 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 44403 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 22152 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5822 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9685 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11948 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 15508 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 16618 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 17 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13177 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 15867 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 44580 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9694 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 8307 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13328 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 21185 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 17795 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2698 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2668 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5378 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 7933 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 44293 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 6116 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 19545 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 10711 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 23231 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1615 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 53284 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2738 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2435 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 429 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11839 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 39957 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 6031 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9819 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 4351 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 14403 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11843 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11531 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 630 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 24427 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 973 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 599 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 24619 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11903 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 3618 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 36637 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 379 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 19676 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 64738 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 25 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 6044 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1955 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 32063 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 3581 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 133 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 12418 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1712 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 14318 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 26587 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 3223 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 41264 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 10004 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 50128 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 19 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1145 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 20749 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 10022 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 36272 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13216 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 177 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 8994 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 15322 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5467 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 29184 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 611 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 17682 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 49325 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 29701 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 34387 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1229 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 3166 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9978 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 3168 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 37115 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9040 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 20178 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 38084 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1456 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 8926 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 15892 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 20347 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1758 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1909 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13082 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 43247 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 14071 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13265 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 17973 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2412 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 25395 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11277 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9867 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 44130 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 20715 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 19945 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 15980 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 32306 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 28833 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11345 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 119 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 24648 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 7292 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 819 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 26385 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 4009 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 29411 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 24474 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 23802 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 12216 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 33070 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1247 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 40222 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 26501 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 29 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 3685 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 25981 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 19219 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 25653 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1962 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2411 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 321 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5205 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5243 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 30911 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 6369 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9686 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 26342 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 31467 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1464 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13763 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1297 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 18411 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9171 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 14003 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1751 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 24261 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 54409 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 790 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 26427 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 64405 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 7834 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2658 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 23589 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 6014 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 6230 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1473 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9038 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 4908 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 32 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13336 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 260 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 4942 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 3372 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 11105 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 70 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13049 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 7912 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 14943 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5167 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 7191 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 25320 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 25818 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 5024 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 398 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 21068 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 10551 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 25416 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 2126 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 18458 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 4912 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 13971 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 9227 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 12764 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 4822 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)

# %%
output
# Out:
# array([[[[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         ...,
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]]],
#
#
#        [[[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         ...,
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]]],
#
#
#        [[[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         ...,
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]]],
#
#
#        ...,
#
#
#        [[[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         ...,
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]]],
#
#
#        [[[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         ...,
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]]],
#
#
#        [[[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         ...,
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]],
#
#         [[0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          ...,
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677],
#          [0.06426451, 0.43406677]]]], dtype=float32)

# %%
# !ls {checkpoint_dir}
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
