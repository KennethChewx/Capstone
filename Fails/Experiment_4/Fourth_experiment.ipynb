# %%
import os
import cv2
import keras
import math
import random
import pathlib
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras import backend as K
from keras.applications.mobilenetv2 import MobileNetV2
from keras.preprocessing import image
from keras.engine import Layer
from keras.applications.inception_resnet_v2 import preprocess_input, InceptionResNetV2
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose, Input, Reshape, merge, concatenate, Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.callbacks import TensorBoard 
from keras.models import Sequential, Model
from keras.layers.core import RepeatVector, Permute
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, gray2rgb
from skimage.transform import resize
from skimage.io import imsave
from skimage import exposure
from skimage.measure import compare_ssim as ssim

# %%
# Memory error, so to feed model in batches
batch_size = 20
train_dir = 'C:/Users/n3rDx/Desktop/Homework Upload/Capstone/images/train/'

# %%
#custom image augmentation function
def custom_preprocessing(image):
    state = random.randint(0,2)
    if state == 0:
        processed_img = exposure.equalize_adapthist((image*1.0/255), clip_limit=0.02)
    elif state == 1:
        processed_img = exposure.equalize_hist(image)
    elif state == 2:
        p2, p98 = np.percentile(image, (2,98))
        processed_img = exposure.rescale_intensity(image, in_range=(p2,p98))
    return processed_img

image_gen = ImageDataGenerator(
        shear_range=0.4,
        zoom_range=0.4,
        vertical_flip=True)
        #preprocessing_function=custom_preprocessing)

# %%
#Load weights
inception = InceptionResNetV2(weights=None, include_top=True)
inception.load_weights('C:/Users/n3rDx/Desktop/Homework Upload/Capstone/inception_weights.h5')
inception.graph = tf.get_default_graph()

# %%
# function to split training set X train, y train and produce augmented images
def image_a_b_gen(batch_size):
    for img in image_gen.flow_from_directory(train_dir, batch_size=batch_size, class_mode=None,shuffle=True):
        grayscaled_rgb = gray2rgb(rgb2gray(img))
        embed = second_input(grayscaled_rgb)
        lab_batch = rgb2lab(img)
        X_train = lab_batch[:,:,:,0]
        X_train = X_train.reshape(X_train.shape+(1,))
        y_train = lab_batch[:,:,:,1:]/128
        yield ([X_train, second_input(grayscaled_rgb)], y_train)

        
#Create input from inception model
def second_input(grayscaled_rgb):
    grayscaled_rgb_resized = []
    for i in grayscaled_rgb:
        i = resize(i, (299, 299, 3), mode='constant')
        grayscaled_rgb_resized.append(i)
    grayscaled_rgb_resized = np.array(grayscaled_rgb_resized)
    grayscaled_rgb_resized = preprocess_input(grayscaled_rgb_resized)
    with inception.graph.as_default():
        embed = inception.predict(grayscaled_rgb_resized)
    return embed

# %%
for i in image_gen.flow_from_directory(train_dir, batch_size=batch_size, class_mode=None,shuffle=True):
    i = i*1.0/255
    grayscaled_rgb = gray2rgb(rgb2gray(i))
    embed = second_input(grayscaled_rgb)
    lab_batch = rgb2lab(i)
    X_train = lab_batch[:,:,:,0]
    X_train = X_train.reshape(X_train.shape+(1,))
    y_train = lab_batch[:,:,:,1:]
    break
# Out:
# Found 2000 images belonging to 1 classes.

# %%
y_train.shape
# Out:
# (20, 256, 256, 2)

# %%
class DSSIMObjective:
    def __init__(self, k1=0.01, k2=0.03, max_value=1.0):
        self.__name__ = 'DSSIMObjective'
        self.k1 = k1
        self.k2 = k2
        self.max_value = max_value
        self.backend = K.backend()

    def __int_shape(self, x):
        return K.int_shape(x) if self.backend == 'tensorflow' else K.shape(x)

    def __call__(self, y_true, y_pred):
        ch = K.shape(y_pred)[-1]

        def _fspecial_gauss(size, sigma):
            #Function to mimic the 'fspecial' gaussian MATLAB function.
            coords = np.arange(0, size, dtype=K.floatx())
            coords -= (size - 1 ) / 2.0
            g = coords**2
            g *= ( -0.5 / (sigma**2) )
            g = np.reshape (g, (1,-1)) + np.reshape(g, (-1,1) )
            g = K.constant ( np.reshape (g, (1,-1)) )
            g = K.softmax(g)
            g = K.reshape (g, (size, size, 1, 1)) 
            g = K.tile (g, (1,1,ch,1))
            return g
                  
        kernel = _fspecial_gauss(11,1.5)

        def reducer(x):
            return K.depthwise_conv2d(x, kernel, strides=(1, 1), padding='valid')

        c1 = (self.k1 * self.max_value) ** 2
        c2 = (self.k2 * self.max_value) ** 2
        
        mean0 = reducer(y_true)
        mean1 = reducer(y_pred)
        num0 = mean0 * mean1 * 2.0
        den0 = K.square(mean0) + K.square(mean1)
        luminance = (num0 + c1) / (den0 + c1)
        
        num1 = reducer(y_true * y_pred) * 2.0
        den1 = reducer(K.square(y_true) + K.square(y_pred))
        c2 *= 1.0 #compensation factor
        cs = (num1 - num0 + c2) / (den1 - den0 + c2)

        ssim_val = K.mean(luminance * cs, axis=(-3, -2) )
        return K.mean( (1.0 - ssim_val ) / 2.0 )

# %%
ssim_loss = DSSIMObjective()

# %%
#Output from inception resnet
inception_input = Input(shape=(1000,))
#Encoder
encoder_input = Input(shape=(256, 256, 1))
encoder_output = Conv2D(64, (3,3), activation='relu', padding='same', strides=2)(encoder_input)    # BS, 128, 128, 64
encoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(encoder_output)             # BS, 128, 128, 128
encoder_output = Conv2D(128, (3,3), activation='relu', padding='same', strides=2)(encoder_output)  # BS, 64, 64, 128
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)             # BS, 64, 64, 256
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same', strides=2)(encoder_output)  # BS, 32, 32, 256
encoder_output = Conv2D(512, (3,3), activation='relu', padding='same')(encoder_output)             # BS, 32, 32, 512
encoder_output = Conv2D(512, (3,3), activation='relu', padding='same')(encoder_output)             # BS, 32, 32, 512
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)             # BS, 32, 32, 256
#Fusion
fusion_output = RepeatVector(32 * 32)(inception_input)                                             # BS, 32, 32, 1000
fusion_output = Reshape(([32, 32, 1000]))(fusion_output)                                           # BS, 32, 32, 1000
fusion_output = concatenate([encoder_output, fusion_output], axis=3)                               # BS, 64, 64, 1256
fusion_output = Conv2D(256, (1, 1), activation='relu', padding='same')(fusion_output)              # BS, 64, 64, 256
#Decoder
decoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(fusion_output)              # BS, 64, 64, 128
decoder_output = Dropout(0.5)(decoder_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)                                              # BS, 128, 128, 128
decoder_output = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output)              # BS, 128, 128, 64
decoder_output = Dropout(0.5)(decoder_output)     
decoder_output = UpSampling2D((2, 2))(decoder_output) 
decoder_output = Conv2D(32, (3,3), activation='relu', padding='same')(decoder_output)              # BS, 128, 128, 32
decoder_output = Dropout(0.5)(decoder_output)
decoder_output = Conv2D(16, (3,3), activation='relu', padding='same')(decoder_output)              # BS, 128, 128, 16
decoder_output = Conv2D(2, (3, 3), activation='tanh', padding='same')(decoder_output)              # BS, 128, 128, 2
decoder_output = UpSampling2D((2, 2))(decoder_output)                                              # BS, 256, 256, 2
model = Model(inputs=[encoder_input, inception_input], outputs=decoder_output)

#Train model
model.compile(optimizer='adam',loss=ssim_loss ,metrics=['mse','mean_absolute_error'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_32 (InputLayer)           (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_995 (Conv2D)             (None, 128, 128, 64) 640         input_32[0][0]
# __________________________________________________________________________________________________
# conv2d_996 (Conv2D)             (None, 128, 128, 128 73856       conv2d_995[0][0]
# __________________________________________________________________________________________________
# conv2d_997 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_996[0][0]
# __________________________________________________________________________________________________
# conv2d_998 (Conv2D)             (None, 64, 64, 256)  295168      conv2d_997[0][0]
# __________________________________________________________________________________________________
# conv2d_999 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_998[0][0]
# __________________________________________________________________________________________________
# conv2d_1000 (Conv2D)            (None, 32, 32, 512)  1180160     conv2d_999[0][0]
# __________________________________________________________________________________________________
# input_31 (InputLayer)           (None, 1000)         0
# __________________________________________________________________________________________________
# conv2d_1001 (Conv2D)            (None, 32, 32, 512)  2359808     conv2d_1000[0][0]
# __________________________________________________________________________________________________
# repeat_vector_14 (RepeatVector) (None, 1024, 1000)   0           input_31[0][0]
# __________________________________________________________________________________________________
# conv2d_1002 (Conv2D)            (None, 32, 32, 256)  1179904     conv2d_1001[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 32, 32, 1000) 0           repeat_vector_14[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 32, 32, 1256) 0           conv2d_1002[0][0]
#                                                                  reshape_14[0][0]
# __________________________________________________________________________________________________
# conv2d_1003 (Conv2D)            (None, 32, 32, 256)  321792      concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_1004 (Conv2D)            (None, 32, 32, 128)  295040      conv2d_1003[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 32, 32, 128)  0           conv2d_1004[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_37 (UpSampling2D) (None, 64, 64, 128)  0           dropout_40[0][0]
# __________________________________________________________________________________________________
# conv2d_1005 (Conv2D)            (None, 64, 64, 64)   73792       up_sampling2d_37[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 64, 64, 64)   0           conv2d_1005[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_38 (UpSampling2D) (None, 128, 128, 64) 0           dropout_41[0][0]
# __________________________________________________________________________________________________
# conv2d_1006 (Conv2D)            (None, 128, 128, 32) 18464       up_sampling2d_38[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 128, 128, 32) 0           conv2d_1006[0][0]
# __________________________________________________________________________________________________
# conv2d_1007 (Conv2D)            (None, 128, 128, 16) 4624        dropout_42[0][0]
# __________________________________________________________________________________________________
# conv2d_1008 (Conv2D)            (None, 128, 128, 2)  290         conv2d_1007[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_39 (UpSampling2D) (None, 256, 256, 2)  0           conv2d_1008[0][0]
# ==================================================================================================
# Total params: 6,541,202
# Trainable params: 6,541,202
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit_generator(image_a_b_gen(batch_size), epochs=1, steps_per_epoch=100)
# Out:
# Epoch 1/1
# Found 2000 images belonging to 1 classes.
# 100/100 [==============================] - 3169s 32s/step - loss: 0.4995 - mean_squared_error: 75.6911 - mean_absolute_error: 5.8122

# %%
model.save('C:/Users/n3rDx/Desktop/Homework Upload/Capstone/Final_final_inception_ssimloss_dropout.h5')

# %%
# Load black and white images
test = []
for filename in os.listdir('C:/Users/n3rDx/Desktop/Homework Upload/Capstone/images/test/test'):
    test.append(img_to_array(load_img('C:/Users/n3rDx/Desktop/Homework Upload/Capstone/images/test/test/'+filename)))
test = np.array(test, dtype=float)
test = 1.0/255*test
test = gray2rgb(rgb2gray(test))
inception_test = second_input(test)
test_input = rgb2lab(test)[:,:,:,0]
test_input = test_input.reshape(test_input.shape+(1,))

# %%
# from gray import, get the AB predictions
output = model.predict([test_input,inception_test])
output = output * 128

# %%
# Output colorizations
for i in range(len(output)):
    canvas = np.zeros((256, 256, 3))
    canvas[:,:,0] = test[i][:,:,0]
    canvas[:,:,1:] = output[i]
    picture = lab2rgb(canvas)
    imsave("C:/Users/n3rDx/Desktop/Homework Upload/Capstone/results/"+str(i)+".jpg", picture)
# Out:
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 524 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:19.961088  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 520 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:20.016127  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 516 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:20.071166  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.123202  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.175239  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.227276  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.279314  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.332350  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.388390  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.447431  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.505473  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.558509  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.614548  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.666586  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.722625  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.776664  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.837707  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.889744  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:20.940779  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 532 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:20.997820  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.053859  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.103894  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.152929  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.203965  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.255001  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.309040  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.360074  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.409109  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.462147  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.514183  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.567221  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.627263  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.690308  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.749349  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.804388  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.858427  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.911464  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:21.964501  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 528 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:22.014536  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.065573  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.116622  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.166645  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.216679  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.268728  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.317750  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.369787  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.421824  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.471860  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.524896  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 536 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:22.578934  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.632974  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.686010  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.738046  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.792084  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.846122  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.899160  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:22.951197  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.002233  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.052268  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.106307  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.160346  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.211380  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.262416  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.320457  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.372495  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.422529  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.474566  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.546617  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.601656  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.652692  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 1488 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:23.703727  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.755766  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.808802  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.860838  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.909874  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:23.958909  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.006942  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.061980  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.125025  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.174059  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.226098  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.277132  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.327167  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.376201  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.429239  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.481276  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.532312  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.592356  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.649395  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 508 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:24.699432  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.750466  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.801502  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.851537  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.901572  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:24.959613  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.013651  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.067689  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 512 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:25.120728  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.172764  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.222799  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.274838  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.325872  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.378909  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.429945  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.478979  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.529015  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.578049  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.628084  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.684124  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.736161  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 568 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:25.787198  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.838233  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.887267  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 468 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:25.938303  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:25.993342  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 464 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:26.045380  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.096416  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.151454  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.207494  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.258529  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.310566  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.363604  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.412638  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.462674  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.514710  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.579756  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.633794  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.682830  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.733866  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.784900  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.835936  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.886972  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.938008  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:26.988044  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.038079  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.091116  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.151159  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.200194  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 548 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:27.251229  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.302265  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.359305  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.415345  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.464380  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.514415  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.562449  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.619489  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.673527  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.723562  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.771597  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 492 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:27.824635  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.876671  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.926707  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:27.977742  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.031780  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.083817  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.136855  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.192894  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.241930  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.294965  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.345000  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.396036  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.446072  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.494108  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.545143  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.595178  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.646213  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.698251  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.748285  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.800321  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.850357  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.899391  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.949427  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:28.998461  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.050499  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\n3rDx\Anaconda3\lib\site-packages\skimage\color\colorconv.py:988: UserWarning: Color data out of range: Z < 0 in 504 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)
# W0703 11:48:29.101534  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.151569  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.203607  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.255644  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.309681  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.360717  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.411753  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.462790  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.512824  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.563860  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.621901  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.672937  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.726976  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.781013  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.835052  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.884087  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.937125  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:29.988160  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:30.039196  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:30.091232  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:30.152276  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:30.207314  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:30.256348  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:30.307385  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:30.356419  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W0703 11:48:30.406454  8584 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
# Memory error, so to feed model in batches
# Image transformer
batch_size = 20

image_gen = ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        rotation_range=20,
        horizontal_flip=True)

# function to split training set X train, y train and produce augmented images
train_dir = '../Capstone/few_images/'
def image_a_b_gen(batch_size):
    for i in image_gen.flow_from_directory(train_dir, batch_size=batch_size,class_mode=None,shuffle=True):
        i = 1.0/255*i
        lab_batch = rgb2lab(i)
        X_train = lab_batch[:,:,:,0]
        X_train = X_train.reshape(X_train.shape+(1,))
        y_train = lab_batch[:,:,:,1:]/128
        yield ([X_train, y_train])

test_gen = ImageDataGenerator()

# %%
#Shared models


#Model A
encoder_output = Conv2D(512, (3,3), activation='relu', padding='same')(encoder_output_shared)
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)
#Model B

#Fusion 
fusion_output = concatenate([encoder_output, global_encoder], axis=3) 
fusion_output = Conv2D(256, (1, 1), activation='relu', padding='same')(fusion_output)
#Decoder
decoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(fusion_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)
decoder_output = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)
decoder_output = Conv2D(32, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = Conv2D(16, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = Conv2D(2, (3, 3), activation='tanh', padding='same')(decoder_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)

model = Model(inputs=encoder_input, outputs=decoder_output)
# Finish model
model.compile(optimizer='adam', loss='mse')

# %%
# Train model
model.fit_generator(image_a_b_gen(batch_size=batch_size), steps_per_epoch=10, epochs=150)
